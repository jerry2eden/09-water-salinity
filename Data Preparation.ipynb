# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Import necessary modules

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read data into dataframe

# %%
bottle_df = pd.read_csv("bottle.csv")
bottle_df.head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  Oxy_µmol/Kg  BtlNum  RecInd  \
# 0       0   10.50  33.440     NaN  25.649    NaN          NaN     NaN       3
# 1       8   10.46  33.440     NaN  25.656    NaN          NaN     NaN       3
# 2      10   10.46  33.437     NaN  25.654    NaN          NaN     NaN       7
# 3      19   10.45  33.420     NaN  25.643    NaN          NaN     NaN       3
# 4      20   10.45  33.421     NaN  25.643    NaN          NaN     NaN       7
#
#    T_prec  T_qual  S_prec  S_qual  P_qual  O_qual  SThtaq  O2Satq  ChlorA  \
# 0     1.0     NaN     2.0     NaN     9.0     9.0     NaN     9.0     NaN
# 1     2.0     NaN     2.0     NaN     9.0     9.0     NaN     9.0     NaN
# 2     2.0     NaN     3.0     NaN     9.0     9.0     NaN     9.0     NaN
# 3     2.0     NaN     2.0     NaN     9.0     9.0     NaN     9.0     NaN
# 4     2.0     NaN     3.0     NaN     9.0     9.0     NaN     9.0     NaN
#
#    Chlqua  Phaeop  Phaqua  PO4uM  PO4q  SiO3uM  SiO3qu  NO2uM  NO2q  NO3uM  \
# 0     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
# 1     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
# 2     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
# 3     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
# 4     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
#
#    NO3q  NH3uM  NH3q  C14As1  C14A1p  C14A1q  C14As2  C14A2p  C14A2q  DarkAs  \
# 0   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
# 1   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
# 2   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
# 3   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
# 4   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
#
#    DarkAp  DarkAq  MeanAs  MeanAp  MeanAq IncTim  LightP  R_Depth  R_TEMP  \
# 0     NaN     9.0     NaN     NaN     9.0    NaN     NaN      0.0   10.50
# 1     NaN     9.0     NaN     NaN     9.0    NaN     NaN      8.0   10.46
# 2     NaN     9.0     NaN     NaN     9.0    NaN     NaN     10.0   10.46
# 3     NaN     9.0     NaN     NaN     9.0    NaN     NaN     19.0   10.45
# 4     NaN     9.0     NaN     NaN     9.0    NaN     NaN     20.0   10.45
#
#    R_POTEMP  R_SALINITY  R_SIGMA  R_SVA  R_DYNHT  R_O2  R_O2Sat  R_SIO3  \
# 0     10.50      33.440    25.64  233.0     0.00   NaN      NaN     NaN
# 1     10.46      33.440    25.65  232.5     0.01   NaN      NaN     NaN
# 2     10.46      33.437    25.65  232.8     0.02   NaN      NaN     NaN
# 3     10.45      33.420    25.64  234.1     0.04   NaN      NaN     NaN
# 4     10.45      33.421    25.64  234.0     0.04   NaN      NaN     NaN
#
#    R_PO4  R_NO3  R_NO2  R_NH4  R_CHLA  R_PHAEO  R_PRES  R_SAMP  DIC1  DIC2  \
# 0    NaN    NaN    NaN    NaN     NaN      NaN       0     NaN   NaN   NaN
# 1    NaN    NaN    NaN    NaN     NaN      NaN       8     NaN   NaN   NaN
# 2    NaN    NaN    NaN    NaN     NaN      NaN      10     NaN   NaN   NaN
# 3    NaN    NaN    NaN    NaN     NaN      NaN      19     NaN   NaN   NaN
# 4    NaN    NaN    NaN    NaN     NaN      NaN      20     NaN   NaN   NaN
#
#    TA1  TA2  pH2  pH1 DIC Quality Comment
# 0  NaN  NaN  NaN  NaN                 NaN
# 1  NaN  NaN  NaN  NaN                 NaN
# 2  NaN  NaN  NaN  NaN                 NaN
# 3  NaN  NaN  NaN  NaN                 NaN
# 4  NaN  NaN  NaN  NaN                 NaN

# %% [markdown]
# ### Rename Columns

# %%
columns = ["Cast Count", "Bottle Count", "Station ID", "Depth ID", "Depth", "Temperature", "Salinity",
           "O2_mL/L", "H2O Density", "O2 Sat", "O2_µmol/Kg", "Bottle No", "Record Indicator",
           "Temperature Precision", "Temperature Quality", "Salinity Precision", "Salinity Quality",
           "Pressure Quality", "O2 Quality", "H20_Density Quality", "O2_Saturation Quality",
           "Chlorophyll-a", "Chlorophyll-a Quality", "Phaeophytin_Concentration", "Phaeophytin Quality", "Phosphate Concentration",
           "Phosphate Quality", "Silicate Concentration", "Silicate Quality", "Nitrite Concentration",
           "Nitrite Quality", "Nitrate Concentration", "Nitrate Quality", "NH4 Concentration", "NH4 Quality",
           "C14_As1", "C14_As1 Precision", "C14_As1 Quality", "C14_As2", "C14_As2 Precision", "C14_As2 Quality",
           "C14_As_Dark", "C14_As_Dark Precision", "C14_As_Dark Quality", "Mean_C14_As", "Mean_C14_As Precision",
           "Mean_C14_As Quality", "Incubation Time", "Light Intensity", "Reported Depth", "Reported Temperature",
           "Reported Potential Temperature", "Reported Salinity", "Reported Potential Density",
           "Reported Specific Volume Anomaly", "Reported Dynamic Height", "Reported O2_mL/L", "Reported O2 Sat",
           "Reported Silicate Concentration", "Reported Phosphate Concentration", "Reported Nitrate Concentration",
           "Reported Nitrite Concentration", "Reported NH4 Concentration", "Reported Chlorophyll-a",
           "Reported Phaeophytin", "Pressure (decibars)", "Sample No", "Dissolved_Inorganic_Carbon1",
           "Dissolved_Inorganic_Carbon2", "Total Alkalinity1", "Total Alkalinity2", "pH2", "pH1",
           "DIC Quality Comment"
          ]

bottle_df.columns = columns

bottle_df.head()
# Out:
#    Cast Count  Bottle Count   Station ID  \
# 0           1             1  054.0 056.0
# 1           1             2  054.0 056.0
# 2           1             3  054.0 056.0
# 3           1             4  054.0 056.0
# 4           1             5  054.0 056.0
#
#                                  Depth ID  Depth  Temperature  Salinity  \
# 0  19-4903CR-HY-060-0930-05400560-0000A-3      0        10.50    33.440
# 1  19-4903CR-HY-060-0930-05400560-0008A-3      8        10.46    33.440
# 2  19-4903CR-HY-060-0930-05400560-0010A-7     10        10.46    33.437
# 3  19-4903CR-HY-060-0930-05400560-0019A-3     19        10.45    33.420
# 4  19-4903CR-HY-060-0930-05400560-0020A-7     20        10.45    33.421
#
#    O2_mL/L  H2O Density  O2 Sat  O2_µmol/Kg  Bottle No  Record Indicator  \
# 0      NaN       25.649     NaN         NaN        NaN                 3
# 1      NaN       25.656     NaN         NaN        NaN                 3
# 2      NaN       25.654     NaN         NaN        NaN                 7
# 3      NaN       25.643     NaN         NaN        NaN                 3
# 4      NaN       25.643     NaN         NaN        NaN                 7
#
#    Temperature Precision  Temperature Quality  Salinity Precision  \
# 0                    1.0                  NaN                 2.0
# 1                    2.0                  NaN                 2.0
# 2                    2.0                  NaN                 3.0
# 3                    2.0                  NaN                 2.0
# 4                    2.0                  NaN                 3.0
#
#    Salinity Quality  Pressure Quality  O2 Quality  H20_Density Quality  \
# 0               NaN               9.0         9.0                  NaN
# 1               NaN               9.0         9.0                  NaN
# 2               NaN               9.0         9.0                  NaN
# 3               NaN               9.0         9.0                  NaN
# 4               NaN               9.0         9.0                  NaN
#
#    O2_Saturation Quality  Chlorophyll-a  Chlorophyll-a Quality  \
# 0                    9.0            NaN                    9.0
# 1                    9.0            NaN                    9.0
# 2                    9.0            NaN                    9.0
# 3                    9.0            NaN                    9.0
# 4                    9.0            NaN                    9.0
#
#    Phaeophytin_Concentration  Phaeophytin Quality  Phosphate Concentration  \
# 0                        NaN                  9.0                      NaN
# 1                        NaN                  9.0                      NaN
# 2                        NaN                  9.0                      NaN
# 3                        NaN                  9.0                      NaN
# 4                        NaN                  9.0                      NaN
#
#    Phosphate Quality  Silicate Concentration  Silicate Quality  \
# 0                9.0                     NaN               9.0
# 1                9.0                     NaN               9.0
# 2                9.0                     NaN               9.0
# 3                9.0                     NaN               9.0
# 4                9.0                     NaN               9.0
#
#    Nitrite Concentration  Nitrite Quality  Nitrate Concentration  \
# 0                    NaN              9.0                    NaN
# 1                    NaN              9.0                    NaN
# 2                    NaN              9.0                    NaN
# 3                    NaN              9.0                    NaN
# 4                    NaN              9.0                    NaN
#
#    Nitrate Quality  NH4 Concentration  NH4 Quality  C14_As1  \
# 0              9.0                NaN          9.0      NaN
# 1              9.0                NaN          9.0      NaN
# 2              9.0                NaN          9.0      NaN
# 3              9.0                NaN          9.0      NaN
# 4              9.0                NaN          9.0      NaN
#
#    C14_As1 Precision  C14_As1 Quality  C14_As2  C14_As2 Precision  \
# 0                NaN              9.0      NaN                NaN
# 1                NaN              9.0      NaN                NaN
# 2                NaN              9.0      NaN                NaN
# 3                NaN              9.0      NaN                NaN
# 4                NaN              9.0      NaN                NaN
#
#    C14_As2 Quality  C14_As_Dark  C14_As_Dark Precision  C14_As_Dark Quality  \
# 0              9.0          NaN                    NaN                  9.0
# 1              9.0          NaN                    NaN                  9.0
# 2              9.0          NaN                    NaN                  9.0
# 3              9.0          NaN                    NaN                  9.0
# 4              9.0          NaN                    NaN                  9.0
#
#    Mean_C14_As  Mean_C14_As Precision  Mean_C14_As Quality Incubation Time  \
# 0          NaN                    NaN                  9.0             NaN
# 1          NaN                    NaN                  9.0             NaN
# 2          NaN                    NaN                  9.0             NaN
# 3          NaN                    NaN                  9.0             NaN
# 4          NaN                    NaN                  9.0             NaN
#
#    Light Intensity  Reported Depth  Reported Temperature  \
# 0              NaN             0.0                 10.50
# 1              NaN             8.0                 10.46
# 2              NaN            10.0                 10.46
# 3              NaN            19.0                 10.45
# 4              NaN            20.0                 10.45
#
#    Reported Potential Temperature  Reported Salinity  \
# 0                           10.50             33.440
# 1                           10.46             33.440
# 2                           10.46             33.437
# 3                           10.45             33.420
# 4                           10.45             33.421
#
#    Reported Potential Density  Reported Specific Volume Anomaly  \
# 0                       25.64                             233.0
# 1                       25.65                             232.5
# 2                       25.65                             232.8
# 3                       25.64                             234.1
# 4                       25.64                             234.0
#
#    Reported Dynamic Height  Reported O2_mL/L  Reported O2 Sat  \
# 0                     0.00               NaN              NaN
# 1                     0.01               NaN              NaN
# 2                     0.02               NaN              NaN
# 3                     0.04               NaN              NaN
# 4                     0.04               NaN              NaN
#
#    Reported Silicate Concentration  Reported Phosphate Concentration  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#    Reported Nitrate Concentration  Reported Nitrite Concentration  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#    Reported NH4 Concentration  Reported Chlorophyll-a  Reported Phaeophytin  \
# 0                         NaN                     NaN                   NaN
# 1                         NaN                     NaN                   NaN
# 2                         NaN                     NaN                   NaN
# 3                         NaN                     NaN                   NaN
# 4                         NaN                     NaN                   NaN
#
#    Pressure (decibars)  Sample No  Dissolved_Inorganic_Carbon1  \
# 0                    0        NaN                          NaN
# 1                    8        NaN                          NaN
# 2                   10        NaN                          NaN
# 3                   19        NaN                          NaN
# 4                   20        NaN                          NaN
#
#    Dissolved_Inorganic_Carbon2  Total Alkalinity1  Total Alkalinity2  pH2  \
# 0                          NaN                NaN                NaN  NaN
# 1                          NaN                NaN                NaN  NaN
# 2                          NaN                NaN                NaN  NaN
# 3                          NaN                NaN                NaN  NaN
# 4                          NaN                NaN                NaN  NaN
#
#    pH1 DIC Quality Comment
# 0  NaN                 NaN
# 1  NaN                 NaN
# 2  NaN                 NaN
# 3  NaN                 NaN
# 4  NaN                 NaN

# %% [markdown]
# ### Check shape of dataframe

# %%
bottle_df.shape
# Out:
# (864863, 74)

# %% [markdown]
# ### Check info of dataframe

# %%
bottle_df.iloc[:, 0:4].head()
# Out:
#    Cast Count  Bottle Count   Station ID  \
# 0           1             1  054.0 056.0
# 1           1             2  054.0 056.0
# 2           1             3  054.0 056.0
# 3           1             4  054.0 056.0
# 4           1             5  054.0 056.0
#
#                                  Depth ID
# 0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1  19-4903CR-HY-060-0930-05400560-0008A-3
# 2  19-4903CR-HY-060-0930-05400560-0010A-7
# 3  19-4903CR-HY-060-0930-05400560-0019A-3
# 4  19-4903CR-HY-060-0930-05400560-0020A-7

# %%
bottle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 74 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Cast Count                        864863 non-null  int64
#  1   Bottle Count                      864863 non-null  int64
#  2   Station ID                        864863 non-null  object
#  3   Depth ID                          864863 non-null  object
#  4   Depth                             864863 non-null  int64
#  5   Temperature                       853900 non-null  float64
#  6   Salinity                          817509 non-null  float64
#  7   O2_mL/L                           696201 non-null  float64
#  8   H2O Density                       812174 non-null  float64
#  9   O2 Sat                            661274 non-null  float64
#  10  O2_µmol/Kg                        661268 non-null  float64
#  11  Bottle No                         118667 non-null  float64
#  12  Record Indicator                  864863 non-null  int64
#  13  Temperature Precision             853900 non-null  float64
#  14  Temperature Quality               23127 non-null   float64
#  15  Salinity Precision                817509 non-null  float64
#  16  Salinity Quality                  74914 non-null   float64
#  17  Pressure Quality                  673755 non-null  float64
#  18  O2 Quality                        184676 non-null  float64
#  19  H20_Density Quality               65823 non-null   float64
#  20  O2_Saturation Quality             217797 non-null  float64
#  21  Chlorophyll-a                     225272 non-null  float64
#  22  Chlorophyll-a Quality             639166 non-null  float64
#  23  Phaeophytin_Concentration         225271 non-null  float64
#  24  Phaeophytin Quality               639170 non-null  float64
#  25  Phosphate Concentration           413317 non-null  float64
#  26  Phosphate Quality                 451786 non-null  float64
#  27  Silicate Concentration            354091 non-null  float64
#  28  Silicate Quality                  510866 non-null  float64
#  29  Nitrite Concentration             337576 non-null  float64
#  30  Nitrite Quality                   529474 non-null  float64
#  31  Nitrate Concentration             337403 non-null  float64
#  32  Nitrate Quality                   529933 non-null  float64
#  33  NH4 Concentration                 64962 non-null   float64
#  34  NH4 Quality                       808299 non-null  float64
#  35  C14_As1                           14432 non-null   float64
#  36  C14_As1 Precision                 12760 non-null   float64
#  37  C14_As1 Quality                   848605 non-null  float64
#  38  C14_As2                           14414 non-null   float64
#  39  C14_As2 Precision                 12742 non-null   float64
#  40  C14_As2 Quality                   848623 non-null  float64
#  41  C14_As_Dark                       22649 non-null   float64
#  42  C14_As_Dark Precision             20457 non-null   float64
#  43  C14_As_Dark Quality               840440 non-null  float64
#  44  Mean_C14_As                       22650 non-null   float64
#  45  Mean_C14_As Precision             20457 non-null   float64
#  46  Mean_C14_As Quality               840439 non-null  float64
#  47  Incubation Time                   14437 non-null   object
#  48  Light Intensity                   18651 non-null   float64
#  49  Reported Depth                    864863 non-null  float64
#  50  Reported Temperature              853900 non-null  float64
#  51  Reported Potential Temperature    818816 non-null  float64
#  52  Reported Salinity                 817509 non-null  float64
#  53  Reported Potential Density        812007 non-null  float64
#  54  Reported Specific Volume Anomaly  812092 non-null  float64
#  55  Reported Dynamic Height           818206 non-null  float64
#  56  Reported O2_mL/L                  696201 non-null  float64
#  57  Reported O2 Sat                   666448 non-null  float64
#  58  Reported Silicate Concentration   354099 non-null  float64
#  59  Reported Phosphate Concentration  413325 non-null  float64
#  60  Reported Nitrate Concentration    337411 non-null  float64
#  61  Reported Nitrite Concentration    337584 non-null  float64
#  62  Reported NH4 Concentration        64982 non-null   float64
#  63  Reported Chlorophyll-a            225276 non-null  float64
#  64  Reported Phaeophytin              225275 non-null  float64
#  65  Pressure (decibars)               864863 non-null  int64
#  66  Sample No                         122006 non-null  float64
#  67  Dissolved_Inorganic_Carbon1       1999 non-null    float64
#  68  Dissolved_Inorganic_Carbon2       224 non-null     float64
#  69  Total Alkalinity1                 2084 non-null    float64
#  70  Total Alkalinity2                 234 non-null     float64
#  71  pH2                               10 non-null      float64
#  72  pH1                               84 non-null      float64
#  73  DIC Quality Comment               55 non-null      object
# dtypes: float64(65), int64(5), object(4)
# memory usage: 488.3+ MB

# %% [markdown]
# **We can see we have quite a number of missing values which will be dealt with going forward**

# %% [markdown]
# **The first four columns have no missing values (they are more of identifiers) so they won't be involved in preprocessing steps like imputation and scaling**

# %% [markdown]
# ### Define a function that will handle the full preprocessing of the data

# %%
def preprocess_data(drop_threshold=70, num_strategy="mean",
                    cat_strategy="most_frequent", fill_value=-999,
                    scaling="standard", file_name="prepared_data.csv"):
    """
    drop_threshold can accept any value between 0 and 100;
    num_strategy can accept "mean", "median" or "constant"
    fill_value: to be specified when num_strategy = "constant"...can take any value
    scaling can accept "standard" or "normal"
    file_name should be specified
    """
    
    data = bottle_df.copy() # make a copy of the original dataframe
    
    """"Drop columns with percent of missing values greater than the threshold"""
    # Get the percentage of missing values for each column
    percent_missing = round(data.isna().sum() / data.shape[0] * 100, 2)
    
    # create a dictionary of the missing values and percent per column
    values = {"Total number of missing values": data.isna().sum(), "Percent of Missing Values": percent_missing}
    
    # convert the dictionary to a dataframe
    missing = pd.DataFrame(values)
    
    # get the columns that fall above the drop_threshold 
    columns_to_drop = missing[missing["Percent of Missing Values"] > drop_threshold].index
    
    # drop the columns
    data.drop(columns_to_drop, axis=1, inplace=True)
    
    # since salinity is the target feature, it should no have missing values
    data.dropna(subset=["Salinity"], inplace=True)
    
    # As earlier stated, exclude the first four columns from the following steps
    new_data = data.iloc[:, 4:]
    
    """split the dataset into continuous and categorical columns""" 
    # create an empty dictionary to hold the number of unique values per column
    uniques = {}
    
    # iterate through the data columns and append the number of unique values in each column to the
    # unique dictionary
    for column in new_data.columns:
        uniques[column] = new_data[column].nunique()
    
    # from careful examination, a threshold of 6 unique values seems to be appropriate for the split
    
    # get the categorical and continuous columns based on the threshold 
    cat_attributes = [column for column in uniques if uniques[column] <= 6]
    num_attributes = [column for column in uniques if uniques[column] > 6]
    
    # Create a new dataframe with the created attributes in a specific order
    new_data = pd.concat([new_data[num_attributes], new_data[cat_attributes]], axis=1)
    
    """Create a pipeline for imputation and scaling"""
    # create a SimpleImputer object for the numerical columns based on the specified strategy
    if num_strategy == "constant":
        numerical_imputer = SimpleImputer(strategy=num_strategy, fill_value=fill_value)
    else:
        numerical_imputer = SimpleImputer(strategy=num_strategy)
    
    # create a SimpleImputer object for the categorical columns based on the specified strategy 
    categorical_imputer = SimpleImputer(strategy=cat_strategy)
    
    # create a scaling object for standardization or normalization
    if scaling == "standard":
        scaler = StandardScaler()
    elif scaling == "normal":
        scaler = MinMaxScaler()
    
    # Create a pipeline to perform imputation and scaling on the numerical attributes
    numerical_pipeline = Pipeline([("imputer", numerical_imputer), ("scaler", scaler)])
    
    # create a full pipeline for both numerical and categorical attributes
    full_pipeline = ColumnTransformer([("num", numerical_pipeline, num_attributes),
                                       ("cat", categorical_imputer, cat_attributes)])
    
    # Preprocess the data using the full pipeline
    prepared_bottle_df = pd.DataFrame(full_pipeline.fit_transform(new_data),
                                     columns=num_attributes + cat_attributes)
    
    # restore the excluded columns
    excluded_columns = data.iloc[:, 0:4]
    excluded_columns.reset_index(drop=True, inplace=True)
    prepared_bottle_df.reset_index(drop=True, inplace=True)
    
    prepared_df = pd.concat([excluded_columns, prepared_bottle_df], axis=1)
    
    # assert that there are no missing values in the prepared dataframe
    assert not all(prepared_df.isna().sum()) 
    
    # save the dataframe to a csv file
    prepared_bottle_df.to_csv(file_name)
    
    return prepared_df

# %% [markdown]
# ### Call the function using the default parameters (70% threshold, mean imputation for numerical attributes, modal imputation for categorical attributes, standardization for numerical attributes)

# %%
processed_bottle = preprocess_data()

# %%
processed_bottle.head()
# Out:
#    Cast Count  Bottle Count   Station ID  \
# 0           1             1  054.0 056.0
# 1           1             2  054.0 056.0
# 2           1             3  054.0 056.0
# 3           1             4  054.0 056.0
# 4           1             5  054.0 056.0
#
#                                  Depth ID     Depth  Temperature  Salinity  \
# 0  19-4903CR-HY-060-0930-05400560-0000A-3 -0.717745    -0.085447 -0.866854
# 1  19-4903CR-HY-060-0930-05400560-0008A-3 -0.691808    -0.094934 -0.866854
# 2  19-4903CR-HY-060-0930-05400560-0010A-7 -0.685324    -0.094934 -0.873349
# 3  19-4903CR-HY-060-0930-05400560-0019A-3 -0.656145    -0.097305 -0.910158
# 4  19-4903CR-HY-060-0930-05400560-0020A-7 -0.652903    -0.097305 -0.907993
#
#         O2_mL/L  H2O Density  O2 Sat    O2_µmol/Kg  Phosphate Concentration  \
# 0  1.428831e-15    -0.146390     0.0 -3.503979e-16             6.203007e-16
# 1  1.428831e-15    -0.140376     0.0 -3.503979e-16             6.203007e-16
# 2  1.428831e-15    -0.142095     0.0 -3.503979e-16             6.203007e-16
# 3  1.428831e-15    -0.151545     0.0 -3.503979e-16             6.203007e-16
# 4  1.428831e-15    -0.151545     0.0 -3.503979e-16             6.203007e-16
#
#    Silicate Concentration  Nitrite Concentration  Nitrate Concentration  \
# 0            9.825168e-16          -3.138183e-16                    0.0
# 1            9.825168e-16          -3.138183e-16                    0.0
# 2            9.825168e-16          -3.138183e-16                    0.0
# 3            9.825168e-16          -3.138183e-16                    0.0
# 4            9.825168e-16          -3.138183e-16                    0.0
#
#    Reported Depth  Reported Temperature  Reported Potential Temperature  \
# 0       -0.717748             -0.085452                       -0.080364
# 1       -0.691811             -0.094939                       -0.089824
# 2       -0.685327             -0.094939                       -0.089824
# 3       -0.656147             -0.097310                       -0.092189
# 4       -0.652905             -0.097310                       -0.092189
#
#    Reported Salinity  Reported Potential Density  \
# 0          -0.864611                   -0.152571
# 1          -0.864611                   -0.143650
# 2          -0.871091                   -0.143650
# 3          -0.907810                   -0.152571
# 4          -0.905650                   -0.152571
#
#    Reported Specific Volume Anomaly  Reported Dynamic Height  \
# 0                          0.129448                -1.134103
# 1                          0.124081                -1.107887
# 2                          0.127301                -1.081672
# 3                          0.141254                -1.029241
# 4                          0.140180                -1.029241
#
#    Reported O2_mL/L  Reported O2 Sat  Reported Silicate Concentration  \
# 0      4.762738e-16     2.129355e-16                     3.929991e-16
# 1      4.762738e-16     2.129355e-16                     3.929991e-16
# 2      4.762738e-16     2.129355e-16                     3.929991e-16
# 3      4.762738e-16     2.129355e-16                     3.929991e-16
# 4      4.762738e-16     2.129355e-16                     3.929991e-16
#
#    Reported Phosphate Concentration  Reported Nitrate Concentration  \
# 0                     -6.202901e-16                   -7.634448e-16
# 1                     -6.202901e-16                   -7.634448e-16
# 2                     -6.202901e-16                   -7.634448e-16
# 3                     -6.202901e-16                   -7.634448e-16
# 4                     -6.202901e-16                   -7.634448e-16
#
#    Reported Nitrite Concentration  Pressure (decibars)  Record Indicator  \
# 0                             0.0            -0.714917               3.0
# 1                             0.0            -0.689255               3.0
# 2                             0.0            -0.682839               7.0
# 3                             0.0            -0.653969               3.0
# 4                             0.0            -0.650761               7.0
#
#    Temperature Precision  Salinity Precision  Pressure Quality  \
# 0                    1.0                 2.0               9.0
# 1                    2.0                 2.0               9.0
# 2                    2.0                 3.0               9.0
# 3                    2.0                 2.0               9.0
# 4                    2.0                 3.0               9.0
#
#    Chlorophyll-a Quality  Phaeophytin Quality  Phosphate Quality  \
# 0                    9.0                  9.0                9.0
# 1                    9.0                  9.0                9.0
# 2                    9.0                  9.0                9.0
# 3                    9.0                  9.0                9.0
# 4                    9.0                  9.0                9.0
#
#    Silicate Quality  Nitrite Quality  Nitrate Quality  NH4 Quality  \
# 0               9.0              9.0              9.0          9.0
# 1               9.0              9.0              9.0          9.0
# 2               9.0              9.0              9.0          9.0
# 3               9.0              9.0              9.0          9.0
# 4               9.0              9.0              9.0          9.0
#
#    C14_As1 Quality  C14_As2 Quality  C14_As_Dark Quality  Mean_C14_As Quality
# 0              9.0              9.0                  9.0                  9.0
# 1              9.0              9.0                  9.0                  9.0
# 2              9.0              9.0                  9.0                  9.0
# 3              9.0              9.0                  9.0                  9.0
# 4              9.0              9.0                  9.0                  9.0
